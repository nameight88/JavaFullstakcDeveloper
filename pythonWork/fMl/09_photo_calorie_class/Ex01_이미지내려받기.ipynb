# %% [markdown]
# 이미지 다운로드는 시간 소요됨
#
# 미리 다운 받은 사진 배포

# %%
#!pip install flickrapi
# Out:
# Collecting flickrapi
#   Downloading flickrapi-2.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: six>=1.5.2 in c:\users\ict03_013\anaconda3\lib\site-packages (from flickrapi) (1.16.0)
# Requirement already satisfied: requests>=2.2.1 in c:\users\ict03_013\anaconda3\lib\site-packages (from flickrapi) (2.31.0)
# Collecting requests-oauthlib>=0.4.0 (from flickrapi)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests-toolbelt>=0.3.1 in c:\users\ict03_013\anaconda3\lib\site-packages (from flickrapi) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ict03_013\anaconda3\lib\site-packages (from requests>=2.2.1->flickrapi) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ict03_013\anaconda3\lib\site-packages (from requests>=2.2.1->flickrapi) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ict03_013\anaconda3\lib\site-packages (from requests>=2.2.1->flickrapi) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ict03_013\anaconda3\lib\site-packages (from requests>=2.2.1->flickrapi) (2024.2.2)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.4.0->flickrapi)
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Downloading flickrapi-2.4.0-py2.py3-none-any.whl (26 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#    ---------------------------------------- 0.0/151.7 kB ? eta -:--:--
#    ---------------------------------------- 151.7/151.7 kB 9.4 MB/s eta 0:00:00
# Installing collected packages: oauthlib, requests-oauthlib, flickrapi
# Successfully installed flickrapi-2.4.0 oauthlib-3.2.2 requests-oauthlib-2.0.0

# %%
# Flickr로 사진 검색해서 다운로드하기
from flickrapi import FlickrAPI
from urllib.request import urlretrieve
from pprint import pprint
import os, time, sys

# AP 키 지정하기--- ( ※ 1)
# key = "<자신의 것을 입력해주세요>"
# secret = "<자신의 것을 입력해주세요>"
key = "1eb22788a01f7bace9649c51c3de8c03"
secret = "87b0bdb8d6b17cc5"
wait_time = 1 # 대기 시간(초)

# 한 번에 대량의 이미지를 내려 받으면 Flickr 서버에 부하가 걸릴 수 있기에 1초 간격으로 내려받고자

# %%
import traceback

# Flickr API로 사진 검색하기 
def go_download(keyword, dir):
    # 저장 경로 지정하기
    savedir = "./image/" + dir
    if not os.path.exists(savedir):
        os.mkdir(savedir)
    # API를 사용해서 다운로드하기 
    flickr = FlickrAPI(key, secret, format='parsed-json')
    res = flickr.photos.search(
      text = keyword,     # 키워드
      per_page = 300,     # 검색할 개수 ( Flickr의 검색 API에서 최대 300개 이미지 제공 )
      media = 'photos',   # 사진 검색
      sort = "relevance", # 키워드 관련도 순서
      safe_search = 1,    # 안전 검색
      extras = 'url_q, license')
    # 결과 확인하기
    photos = res['photos']
    pprint(photos)
    try:
      # 1장씩 다운로드하기
      for i, photo in enumerate(photos['photo']):
        url_q = photo['url_q']
        filepath = savedir + '/' + photo['id'] + '.jpg'
        if os.path.exists(filepath): continue
        print(str(i + 1) + ":download=", url_q)
        urlretrieve(url_q, filepath)
        time.sleep(wait_time)
    except:
        traceback.print_exc()

# %% [markdown]
# 위의 함수를 실행전에 디렉토리가 먼저 생성되어 있어야 한다
#
#  - image
#       - sushi
#       - salad
#       - tofu

# %%
# 키워드와 디렉터리 이름 지정해서 다운로드하기 
go_download('초밥', 'sushi')
# Out:
# {'page': 1,
#  'pages': 3,
#  'perpage': 300,
#  'photo': [{'farm': 6,
#             'height_q': 150,
#             'id': '9596303145',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '97325801@N04',
#             'secret': 'f619c1ae2d',
#             'server': '5523',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/5523/9596303145_f619c1ae2d_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '9599095698',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '97325801@N04',
#             'secret': 'c30f68870b',
#             'server': '3769',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/3769/9599095698_c30f68870b_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '9599095478',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '97325801@N04',
#             'secret': 'a0fb4ddce1',
#             'server': '7361',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/7361/9599095478_a0fb4ddce1_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '9227638860',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '23344263@N07',
#             'secret': '5c3d5500d4',
#             'server': '3756',
#             'title': '남가 초밥',
#             'url_q': 'https://live.staticflickr.com/3756/9227638860_5c3d5500d4_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '33523410825',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '23344263@N07',
#             'secret': '052f8063ca',
#             'server': '2903',
#             'title': '#코스트코 #초밥',
#             'url_q': 'https://live.staticflickr.com/2903/33523410825_052f8063ca_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '115273651',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '67347235@N00',
#             'secret': '614e2ab73d',
#             'server': '55',
#             'title': '롯데마트에서 산 초밥',
#             'url_q': 'https://live.staticflickr.com/55/115273651_614e2ab73d_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4617258107',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '6',
#             'owner': '29180485@N07',
#             'secret': 'ebf9cce42a',
#             'server': '4040',
#             'title': '간만에 어머니랑 초밥!!!',
#             'url_q': 'https://live.staticflickr.com/4040/4617258107_ebf9cce42a_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2594339081',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': 'f137df97d7',
#             'server': '3004',
#             'title': '또 연어. 초밥 매니아~',
#             'url_q': 'https://live.staticflickr.com/3004/2594339081_f137df97d7_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2546508871',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': 'cf3f2e2b14',
#             'server': '2057',
#             'title': '또 초밥. 그런데, 장어가 ..',
#             'url_q': 'https://live.staticflickr.com/2057/2546508871_cf3f2e2b14_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '8365544608',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '14340225@N03',
#             'secret': 'be87eb8700',
#             'server': '8512',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/8512/8365544608_be87eb8700_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2272700235',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': '166301a38f',
#             'server': '2337',
#             'title': '나도 은근히 초밥 매니아.',
#             'url_q': 'https://live.staticflickr.com/2337/2272700235_166301a38f_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2198722277',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': '87b344dd50',
#             'server': '2012',
#             'title': '또 초밥. 진정한 음식 염장..',
#             'url_q': 'https://live.staticflickr.com/2012/2198722277_87b344dd50_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2538351058',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': 'f525f059d2',
#             'server': '2406',
#             'title': '또 초밥. 이정도면 초밥 좋..',
#             'url_q': 'https://live.staticflickr.com/2406/2538351058_f525f059d2_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '8663734717',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '56298706@N00',
#             'secret': '079aee75ea',
#             'server': '8239',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/8239/8663734717_079aee75ea_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '3755325944',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '14340225@N03',
#             'secret': '69fe7c8f64',
#             'server': '2472',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/2472/3755325944_69fe7c8f64_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4367100863',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11499044@N08',
#             'secret': '2ca73c7283',
#             'server': '2696',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/2696/4367100863_2ca73c7283_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4347508999',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11499044@N08',
#             'secret': 'e7d1248bb4',
#             'server': '4050',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/4050/4347508999_e7d1248bb4_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '10170533083',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '37934744@N02',
#             'secret': '6b01b6fa40',
#             'server': '3797',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/3797/10170533083_6b01b6fa40_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6580102197',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '37934744@N02',
#             'secret': '27031a08a1',
#             'server': '7141',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/7141/6580102197_27031a08a1_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5273893013',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '37934744@N02',
#             'secret': 'c8cbb0006f',
#             'server': '5122',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/5122/5273893013_c8cbb0006f_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2914638728',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '10633825@N04',
#             'secret': '4be4bb415d',
#             'server': '3005',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/3005/2914638728_4be4bb415d_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '13699444764',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '84404598@N02',
#             'secret': 'de9cf41488',
#             'server': '2821',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/2821/13699444764_de9cf41488_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4362282117',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '24675118@N08',
#             'secret': 'db551ecabf',
#             'server': '4064',
#             'title': '스시',
#             'url_q': 'https://live.staticflickr.com/4064/4362282117_db551ecabf_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3439852165',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': 'b765252ec7',
#             'server': '3324',
#             'title': '초밥!',
#             'url_q': 'https://live.staticflickr.com/3324/3439852165_b765252ec7_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3656988932',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': '5559695d69',
#             'server': '3402',
#             'title': '초밥!!!',
#             'url_q': 'https://live.staticflickr.com/3402/3656988932_5559695d69_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '9313104038',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '98941613@N02',
#             'secret': 'e1c972ce44',
#             'server': '3781',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/3781/9313104038_e1c972ce44_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '364317848',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '88939862@N00',
#             'secret': 'beef335422',
#             'server': '146',
#             'title': '롤',
#             'url_q': 'https://live.staticflickr.com/146/364317848_beef335422_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '364317858',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '88939862@N00',
#             'secret': '460dcce0e4',
#             'server': '102',
#             'title': '새우스시',
#             'url_q': 'https://live.staticflickr.com/102/364317858_460dcce0e4_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2473738908',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '24675118@N08',
#             'secret': 'd3f7113e4b',
#             'server': '3051',
#             'title': '桜エビ',
#             'url_q': 'https://live.staticflickr.com/3051/2473738908_d3f7113e4b_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '364317864',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '88939862@N00',
#             'secret': 'c67dacff6b',
#             'server': '164',
#             'title': '참치스시',
#             'url_q': 'https://live.staticflickr.com/164/364317864_c67dacff6b_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '7378156626',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '79932701@N06',
#             'secret': '74a82f5837',
#             'server': '7092',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/7092/7378156626_74a82f5837_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '7982241865',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '77515410@N08',
#             'secret': '2f88818874',
#             'server': '8311',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/8311/7982241865_2f88818874_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6154654495',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': 'be27713398',
#             'server': '6082',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/6082/6154654495_be27713398_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6854043060',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '87808135@N00',
#             'secret': '286ac4700c',
#             'server': '6107',
#             'title': '토레토레 어시장',
#             'url_q': 'https://live.staticflickr.com/6107/6854043060_286ac4700c_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4350359859',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '47394853@N04',
#             'secret': '966474b3a6',
#             'server': '4047',
#             'title': '동생이 초밥을 사왔네 +_+',
#             'url_q': 'https://live.staticflickr.com/4047/4350359859_966474b3a6_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6154639033',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': '8332c2ede4',
#             'server': '6084',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/6084/6154639033_8332c2ede4_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2738555364',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': '305fdc0aa8',
#             'server': '3150',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/3150/2738555364_305fdc0aa8_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '364317862',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '88939862@N00',
#             'secret': '7168bc5e1f',
#             'server': '157',
#             'title': '장어스시',
#             'url_q': 'https://live.staticflickr.com/157/364317862_7168bc5e1f_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '4666293342',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '44632924@N05',
#             'secret': '39bf6d12da',
#             'server': '1276',
#             'title': '야근의 묘미 어쩐일로 이런 ..',
#             'url_q': 'https://live.staticflickr.com/1276/4666293342_39bf6d12da_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4493093951',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '4',
#             'owner': '59658513@N00',
#             'secret': 'fd34a26f30',
#             'server': '2799',
#             'title': '맛있다옹',
#             'url_q': 'https://live.staticflickr.com/2799/4493093951_fd34a26f30_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3962530402',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '42993653@N07',
#             'secret': '0cbb1c4ef7',
#             'server': '3499',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/3499/3962530402_0cbb1c4ef7_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6901616871',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '6',
#             'owner': '29180485@N07',
#             'secret': '44489a0124',
#             'server': '7210',
#             'title': '주말이니 동생님과 외식',
#             'url_q': 'https://live.staticflickr.com/7210/6901616871_44489a0124_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '5889913514',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': '1c76a166b8',
#             'server': '6023',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/6023/5889913514_1c76a166b8_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5593852399',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '29549416@N05',
#             'secret': 'f322052597',
#             'server': '5265',
#             'title': '2011.4.3',
#             'url_q': 'https://live.staticflickr.com/5265/5593852399_f322052597_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '9169305943',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '97692946@N06',
#             'secret': '455ce9b290',
#             'server': '5507',
#             'title': '_IGP1223',
#             'url_q': 'https://live.staticflickr.com/5507/9169305943_455ce9b290_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '5736064865',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': 'c8b539852b',
#             'server': '2721',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/2721/5736064865_c8b539852b_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '9599095168',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '97325801@N04',
#             'secret': '764fae3cd6',
#             'server': '7353',
#             'title': '스시히로바',
#             'url_q': 'https://live.staticflickr.com/7353/9599095168_764fae3cd6_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6189625424',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '36877757@N05',
#             'secret': '5e1ea027d5',
#             'server': '6128',
#             'title': '간만의 초밥',
#             'url_q': 'https://live.staticflickr.com/6128/6189625424_5e1ea027d5_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3076416085',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': 'c1a4a08d0f',
#             'server': '3061',
#             'title': '참치대뱃살 초밥',
#             'url_q': 'https://live.staticflickr.com/3061/3076416085_c1a4a08d0f_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6782442058',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '42778069@N06',
#             'secret': '3a35649d2c',
#             'server': '7063',
#             'title': '오늘 먹은 저녁 (1)',
#             'url_q': 'https://live.staticflickr.com/7063/6782442058_3a35649d2c_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '3909359718',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '29549416@N05',
#             'secret': '6979dc2298',
#             'server': '2461',
#             'title': '2009.9.10',
#             'url_q': 'https://live.staticflickr.com/2461/3909359718_6979dc2298_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3918842460',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '40384364@N03',
#             'secret': 'd4265ae1bb',
#             'server': '3508',
#             'title': '밥먹을때는 밥만먹어야죠.. ..',
#             'url_q': 'https://live.staticflickr.com/3508/3918842460_d4265ae1bb_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4042020925',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '29549416@N05',
#             'secret': 'ca2135ccda',
#             'server': '2668',
#             'title': '2009.10.23',
#             'url_q': 'https://live.staticflickr.com/2668/4042020925_ca2135ccda_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4021363868',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': '489f288b45',
#             'server': '2429',
#             'title': '맛있다…',
#             'url_q': 'https://live.staticflickr.com/2429/4021363868_489f288b45_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4020572729',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': '0ba507c6fe',
#             'server': '2638',
#             'title': '맛있다.',
#             'url_q': 'https://live.staticflickr.com/2638/4020572729_0ba507c6fe_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '42050638502',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '156630706@N03',
#             'secret': '23c2f486c1',
#             'server': '977',
#             'title': '꼬지 맛있쪙',
#             'url_q': 'https://live.staticflickr.com/977/42050638502_23c2f486c1_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6989443639',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '67347235@N00',
#             'secret': '81763bde42',
#             'server': '7051',
#             'title': '롯데마트 초밥',
#             'url_q': 'https://live.staticflickr.com/7051/6989443639_81763bde42_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '2490681171',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': 'cb6b49ca00',
#             'server': '2289',
#             'title': '이럴수가! 장어가 없어!',
#             'url_q': 'https://live.staticflickr.com/2289/2490681171_cb6b49ca00_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6782443630',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '42778069@N06',
#             'secret': 'ca3061a805',
#             'server': '7194',
#             'title': '오늘 먹은 저녁 (1)',
#             'url_q': 'https://live.staticflickr.com/7194/6782443630_ca3061a805_q.jpg',
#             'width_q': 150},
#            {'farm': 66,
#             'height_q': 150,
#             'id': '53734641112',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '200780782@N08',
#             'secret': '41f96718c2',
#             'server': '65535',
#             'title': '9',
#             'url_q': 'https://live.staticflickr.com/65535/53734641112_41f96718c2_q.jpg',
#             'width_q': 150},
#            {'farm': 66,
#             'height_q': 150,
#             'id': '53734641122',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '200780782@N08',
#             'secret': 'e804150fbb',
#             'server': '65535',
#             'title': '5',
#             'url_q': 'https://live.staticflickr.com/65535/53734641122_e804150fbb_q.jpg',
#             'width_q': 150},
#            {'farm': 66,
#             'height_q': 150,
#             'id': '53735772313',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '200780782@N08',
#             'secret': '4d88f7a10e',
#             'server': '65535',
#             'title': '6',
#             'url_q': 'https://live.staticflickr.com/65535/53735772313_4d88f7a10e_q.jpg',
#             'width_q': 150},
#            {'farm': 66,
#             'height_q': 150,
#             'id': '53734641057',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '200780782@N08',
#             'secret': '1de6284f0c',
#             'server': '65535',
#             'title': '10',
#             'url_q': 'https://live.staticflickr.com/65535/53734641057_1de6284f0c_q.jpg',
#             'width_q': 150},
#            {'farm': 66,
#             'height_q': 150,
#             'id': '53735571396',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '200780782@N08',
#             'secret': 'da413ae34e',
#             'server': '65535',
#             'title': '8',
#             'url_q': 'https://live.staticflickr.com/65535/53735571396_da413ae34e_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '33354510381',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '152864136@N07',
#             'secret': 'e7944696ef',
#             'server': '3920',
#             'title': '초밥',
#             'url_q': 'https://live.staticflickr.com/3920/33354510381_e7944696ef_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3254839090',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '30255546@N02',
#             'secret': '666d9342f8',
#             'server': '3122',
#             'title': 'Soybean Curd with Rice (유부 초밥=YuBu ChoBap)',
#             'url_q': 'https://live.staticflickr.com/3122/3254839090_666d9342f8_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '3883965190',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '41687858@N08',
#             'secret': '1ff82734c7',
#             'server': '2593',
#             'title': '초밥 먹으러 왔어요~',
#             'url_q': 'https://live.staticflickr.com/2593/3883965190_1ff82734c7_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '14604999840',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '126415358@N06',
#             'secret': '74b0142c01',
#             'server': '5586',
#             'title': '#초밥#스시#sushi#노량진#먹스타그램',
#             'url_q': 'https://live.staticflickr.com/5586/14604999840_74b0142c01_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '45770243534',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '127701072@N05',
#             'secret': 'dbdfd6e7c7',
#             'server': '4864',
#             'title': 'Sushi, Japan',
#             'url_q': 'https://live.staticflickr.com/4864/45770243534_dbdfd6e7c7_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2778892153',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '39117859@N00',
#             'secret': '38a329ae7b',
#             'server': '3076',
#             'title': 'Delicious Sushi/초밥',
#             'url_q': 'https://live.staticflickr.com/3076/2778892153_38a329ae7b_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2779748226',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '39117859@N00',
#             'secret': '6cd432f238',
#             'server': '3083',
#             'title': 'School Sushi/초밥',
#             'url_q': 'https://live.staticflickr.com/3083/2779748226_6cd432f238_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '35865964001',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '135405619@N07',
#             'secret': 'e455d21ea8',
#             'server': '4297',
#             'title': 'Sushi',
#             'url_q': 'https://live.staticflickr.com/4297/35865964001_e455d21ea8_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '8321083556',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '91629146@N02',
#             'secret': '82fb4e703e',
#             'server': '8501',
#             'title': 'Sushi 초밥',
#             'url_q': 'https://live.staticflickr.com/8501/8321083556_82fb4e703e_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '7987365371',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '54782710@N07',
#             'secret': '8d1fc45bf2',
#             'server': '8456',
#             'title': '간단하게 초밥',
#             'url_q': 'https://live.staticflickr.com/8456/7987365371_8d1fc45bf2_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '14615751310',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '126415358@N06',
#             'secret': '7d8d76e625',
#             'server': '3924',
#             'title': '#가로수길 #세로수길 #갓덴스시 #회전초밥 #초밥 #회 #먹스타그램',
#             'url_q': 'https://live.staticflickr.com/3924/14615751310_7d8d76e625_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2595948649',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '12608639@N03',
#             'secret': '9c82ba2225',
#             'server': '3287',
#             'title': 'Tamago sushi',
#             'url_q': 'https://live.staticflickr.com/3287/2595948649_9c82ba2225_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '8958258251',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11238204@N08',
#             'secret': '056314225d',
#             'server': '7334',
#             'title': '초밥 수업',
#             'url_q': 'https://live.staticflickr.com/7334/8958258251_056314225d_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '35159195444',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '135405619@N07',
#             'secret': '17e30a35b0',
#             'server': '4323',
#             'title': 'Sushi',
#             'url_q': 'https://live.staticflickr.com/4323/35159195444_17e30a35b0_q.jpg',
#             'width_q': 150},
#            {'farm': 66,
#             'height_q': 150,
#             'id': '50753685703',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '14340225@N03',
#             'secret': 'feaea1eb80',
#             'server': '65535',
#             'title': '초밥 Sushi',
#             'url_q': 'https://live.staticflickr.com/65535/50753685703_feaea1eb80_q.jpg',
#             'width_q': 150},
#            {'farm': 66,
#             'height_q': 150,
#             'id': '49882601867',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '14340225@N03',
#             'secret': '2f267e0059',
#             'server': '65535',
#             'title': '초밥 Sushi',
#             'url_q': 'https://live.staticflickr.com/65535/49882601867_2f267e0059_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5348422111',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '50650870@N02',
#             'secret': '6f74e2735c',
#             'server': '5250',
#             'title': '연어 초밥 @ 스시앤스시',
#             'url_q': 'https://live.staticflickr.com/5250/5348422111_6f74e2735c_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5348410141',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '50650870@N02',
#             'secret': '2336ba3142',
#             'server': '5130',
#             'title': '멍게 초밥 @ 스시앤스시',
#             'url_q': 'https://live.staticflickr.com/5130/5348410141_2336ba3142_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2785815174',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '48432348@N00',
#             'secret': '36c7a987db',
#             'server': '3234',
#             'title': '비도 오는데, 내가 좋아하는..',
#             'url_q': 'https://live.staticflickr.com/3234/2785815174_36c7a987db_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3775320116',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11983072@N05',
#             'secret': 'a0297feceb',
#             'server': '3440',
#             'title': '초밥이 이정도는 돼야지. 오..',
#             'url_q': 'https://live.staticflickr.com/3440/3775320116_a0297feceb_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '2627082961',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '15134851@N00',
#             'secret': '9c66c6666b',
#             'server': '3165',
#             'title': '가족과 함께 스타피쉬에서 외..',
#             'url_q': 'https://live.staticflickr.com/3165/2627082961_9c66c6666b_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '22878598231',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '130554307@N07',
#             'secret': '83a22cefb8',
#             'server': '5745',
#             'title': '마더와 초밥.',
#             'url_q': 'https://live.staticflickr.com/5745/22878598231_83a22cefb8_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '35828039922',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '135405619@N07',
#             'secret': 'a883bfc176',
#             'server': '4299',
#             'title': 'Sushi',
#             'url_q': 'https://live.staticflickr.com/4299/35828039922_a883bfc176_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '8166708948',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '63167781@N07',
#             'secret': 'fe7f04bfa3',
#             'server': '8198',
#             'title': '다미진횟집 초밥',
#             'url_q': 'https://live.staticflickr.com/8198/8166708948_fe7f04bfa3_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4914047837',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '14340225@N03',
#             'secret': '8826bb79fb',
#             'server': '4119',
#             'title': '정어리 초밥(이와시)',
#             'url_q': 'https://live.staticflickr.com/4119/4914047837_8826bb79fb_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6854043222',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '87808135@N00',
#             'secret': '9a56518b78',
#             'server': '6240',
#             'title': '토레토레 어시장',
#             'url_q': 'https://live.staticflickr.com/6240/6854043222_9a56518b78_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4979210264',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11499044@N08',
#             'secret': 'a277e44e82',
#             'server': '4108',
#             'title': '유부 초밥',
#             'url_q': 'https://live.staticflickr.com/4108/4979210264_a277e44e82_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5371585020',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '27133654@N06',
#             'secret': '5265bd79b1',
#             'server': '5084',
#             'title': '헉 초밥',
#             'url_q': 'https://live.staticflickr.com/5084/5371585020_5265bd79b1_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6920226753',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '29565988@N04',
#             'secret': 'b667236ece',
#             'server': '7199',
#             'title': '간만에 초밥 먹는다해',
#             'url_q': 'https://live.staticflickr.com/7199/6920226753_b667236ece_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '35610026690',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '135405619@N07',
#             'secret': 'd0e59863a4',
#             'server': '4309',
#             'title': 'Sushi',
#             'url_q': 'https://live.staticflickr.com/4309/35610026690_d0e59863a4_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '27264855260',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '3',
#             'owner': '133230301@N04',
#             'secret': 'baf8f43713',
#             'server': '7572',
#             'title': '연어회 무한리필',
#             'url_q': 'https://live.staticflickr.com/7572/27264855260_baf8f43713_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '8166709090',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '63167781@N07',
#             'secret': '6b2b9bd9b7',
#             'server': '8477',
#             'title': '다미진횟집 초밥',
#             'url_q': 'https://live.staticflickr.com/8477/8166709090_6b2b9bd9b7_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4351080075',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '4',
#             'owner': '9472208@N08',
#             'secret': 'fa8100b7fa',
#             'server': '2722',
#             'title': '도시인 초밥 부페 (City Person Sushi Buffet) Gangneung',
#             'url_q': 'https://live.staticflickr.com/2722/4351080075_fa8100b7fa_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '35188178103',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '135405619@N07',
#             'secret': 'e72be1bfb4',
#             'server': '4307',
#             'title': 'Sushi',
#             'url_q': 'https://live.staticflickr.com/4307/35188178103_e72be1bfb4_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '15030009366',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '27097317@N00',
#             'secret': 'b06d6165ee',
#             'server': '3853',
#             'title': '아내님이 싸온 초밥~',
#             'url_q': 'https://live.staticflickr.com/3853/15030009366_b06d6165ee_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '8166706246',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '63167781@N07',
#             'secret': '251307a50e',
#             'server': '8059',
#             'title': '다미진횟집 초밥',
#             'url_q': 'https://live.staticflickr.com/8059/8166706246_251307a50e_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6028696662',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': '43d0a36a7e',
#             'server': '6192',
#             'title': '초밥 @ 경스시',
#             'url_q': 'https://live.staticflickr.com/6192/6028696662_43d0a36a7e_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '8959450002',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '11238204@N08',
#             'secret': 'd98992ce29',
#             'server': '7450',
#             'title': '초밥 승윤이작',
#             'url_q': 'https://live.staticflickr.com/7450/8959450002_d98992ce29_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '8166677339',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '63167781@N07',
#             'secret': '29496e95ac',
#             'server': '7124',
#             'title': '다미진횟집 초밥',
#             'url_q': 'https://live.staticflickr.com/7124/8166677339_29496e95ac_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4493175680',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '42777912@N03',
#             'secret': '9bfbb9d102',
#             'server': '2766',
#             'title': '초밥 스타트~!',
#             'url_q': 'https://live.staticflickr.com/2766/4493175680_9bfbb9d102_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '15231919037',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '6',
#             'owner': '65522415@N00',
#             'secret': '2822eda4e3',
#             'server': '2949',
#             'title': '비오는날은 야근하면서 초밥.',
#             'url_q': 'https://live.staticflickr.com/2949/15231919037_2822eda4e3_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4970381791',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': 'bfc7250c5d',
#             'server': '4107',
#             'title': '초밥 @ 스시웨이',
#             'url_q': 'https://live.staticflickr.com/4107/4970381791_bfc7250c5d_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6045070211',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': '4f2ab0427a',
#             'server': '6088',
#             'title': '초밥 @ 경스시',
#             'url_q': 'https://live.staticflickr.com/6088/6045070211_4f2ab0427a_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '9515982906',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '97860040@N03',
# ...
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': 'cdbf43833d',
#             'server': '3498',
#             'title': '주도로아부리 초밥 @ 사까나야',
#             'url_q': 'https://live.staticflickr.com/3498/4628528580_cdbf43833d_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4627902299',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': '16098b07a7',
#             'server': '4027',
#             'title': '가쯔오 아보카도 초밥 @ 사까나야',
#             'url_q': 'https://live.staticflickr.com/4027/4627902299_16098b07a7_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '22843051694',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '126884061@N08',
#             'secret': '8a9ceeea0d',
#             'server': '5668',
#             'title': ': #초밥 으로 살짝 배채우고 #참치 #폭풍흡입 . . . #20151201 #화요일 #한국 #서울 '
#                      '#천호 #쿠우쿠우 #먹스타그램 #맛스타그램 #씨푸드뷔페 #푸딩 #먹부림 #먹방 #인스타푸드 '
#                      '#INSTAFOOD #KOREAFOOD#韓国料理#韩国食品 #KOREA #韓国 #韩国 #소니 #SONY '
#                      '#RX100M3 #4O3FOOD',
#             'url_q': 'https://live.staticflickr.com/5668/22843051694_8a9ceeea0d_q.jpg',
#             'width_q': 150},
#            {'farm': 7,
#             'height_q': 150,
#             'id': '6132214334',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '51312335@N02',
#             'secret': '9445234280',
#             'server': '6078',
#             'title': '[식미투] 초밥! 잠실 석촌..',
#             'url_q': 'https://live.staticflickr.com/6078/6132214334_9445234280_q.jpg',
#             'width_q': 150},
#            {'farm': 66,
#             'height_q': 150,
#             'id': '51273768131',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '14340225@N03',
#             'secret': 'a942cf097f',
#             'server': '65535',
#             'title': '흑임자 넣은 계란 초밥 Egg Sushi',
#             'url_q': 'https://live.staticflickr.com/65535/51273768131_a942cf097f_q.jpg',
#             'width_q': 150},
#            {'farm': 1,
#             'height_q': 150,
#             'id': '23449039415',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '126884061@N08',
#             'secret': 'd65cc557ef',
#             'server': '636',
#             'title': ': #불토 시작은 #초밥 으로 배부터 채우는걸로!! . . . #20151128 #토요일 #한국 '
#                      '#서울 #신사 #가로수길 #기다스시 #먹스타그램 #맛스타그램 #술스타그램 #먹부림 #먹방 #인스타푸드 '
#                      '#INSTAFOOD #KOREAFOOD#韓国料理#韩国食品 #KOREA #韓国 #韩国 #소니 #SONY '
#                      '#RX100M3 #4O3',
#             'url_q': 'https://live.staticflickr.com/636/23449039415_d65cc557ef_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5372281440',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '42738843@N04',
#             'secret': 'c77ac89d59',
#             'server': '5242',
#             'title': '초밥 먹고 32000… 잊지..',
#             'url_q': 'https://live.staticflickr.com/5242/5372281440_c77ac89d59_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4312431289',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '36961744@N05',
#             'secret': '2175ffa54e',
#             'server': '4056',
#             'title': '초밥 파티중. 대미는 시로미..',
#             'url_q': 'https://live.staticflickr.com/4056/4312431289_2175ffa54e_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '20744099632',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '1',
#             'owner': '22733242@N04',
#             'secret': '663690786e',
#             'server': '5675',
#             'title': '다이와스시(大和寿司, Daiwa Sushi) 스시(寿司,Sushi,초밥)',
#             'url_q': 'https://live.staticflickr.com/5675/20744099632_663690786e_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '18305737661',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '6',
#             'owner': '34147534@N06',
#             'secret': '43b2176641',
#             'server': '8758',
#             'title': '[coolpix]  롯데몰 어촌계 2015.05.30_16',
#             'url_q': 'https://live.staticflickr.com/8758/18305737661_43b2176641_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '4059829192',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '44248278@N08',
#             'secret': 'c0507498a4',
#             'server': '2573',
#             'title': '초밥 aka sushi :)',
#             'url_q': 'https://live.staticflickr.com/2573/4059829192_c0507498a4_q.jpg',
#             'width_q': 150},
#            {'farm': 9,
#             'height_q': 150,
#             'id': '30071030021',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '142452128@N03',
#             'secret': '9f24d71e08',
#             'server': '8277',
#             'title': '#맛없으면안올림 [steve😎 맘대로 음식평🍴; #나마스시 #동대문역사문화공원 #스시정식 (총점 '
#                      '3.7)] 1. 맛 4  1) 회무침, 꽁치조림, 각종 채소  2) 4종류 초밥, 6종류 회  3) '
#                      '우동, 튀김  4) 과일 3조각, 매실차 - 3인분에 맞는 적절한 구성. 회들 대체로 싱싱해 보였음. '
#                      '맛있었고 깔끔.  11:20~12:40까지 있었는데, 중간에 테이블 꽉 찰 때부터 예감이 왔음. 2. '
#                      '가격 3.',
#             'url_q': 'https://live.staticflickr.com/8277/30071030021_9f24d71e08_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '33643956760',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '152571434@N02',
#             'secret': 'f66cc26f64',
#             'server': '2871',
#             'title': '#자향미한의원#튼살#흉터#맛집#일상#강남#서초#침#이름#서울#봄#모공#미모#미인#화장품#이웃#맛스타#드라마#영화#tv#방송#2017#동안#다이어트#비만#에스라인#꿀벅지#간식#밥#한약#화상흉터#식이요법#화상자국#한의사#강좌#마케팅#수유#임신#회식#초밥',
#             'url_q': 'https://live.staticflickr.com/2871/33643956760_f66cc26f64_q.jpg',
#             'width_q': 150},
#            {'farm': 5,
#             'height_q': 150,
#             'id': '4476395091',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': '40682e479b',
#             'server': '4066',
#             'title': '모둠 초밥 세트',
#             'url_q': 'https://live.staticflickr.com/4066/4476395091_40682e479b_q.jpg',
#             'width_q': 150},
#            {'farm': 66,
#             'height_q': 150,
#             'id': '50753685638',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '14340225@N03',
#             'secret': 'c175bc71df',
#             'server': '65535',
#             'title': '고등어 초절임 초밥 + 성게알 군칸마키 Mackerel Sushi + Uni Sushi',
#             'url_q': 'https://live.staticflickr.com/65535/50753685638_c175bc71df_q.jpg',
#             'width_q': 150},
#            {'farm': 3,
#             'height_q': 150,
#             'id': '5706715036',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '28502740@N06',
#             'secret': '1d3e904601',
#             'server': '2242',
#             'title': '알밥정식 @ 오니 초밥',
#             'url_q': 'https://live.staticflickr.com/2242/5706715036_1d3e904601_q.jpg',
#             'width_q': 150},
#            {'farm': 8,
#             'height_q': 150,
#             'id': '6928563933',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '42778069@N06',
#             'secret': '6f6cd8aedd',
#             'server': '7208',
#             'title': '오늘 먹은 저녁 (2)',
#             'url_q': 'https://live.staticflickr.com/7208/6928563933_6f6cd8aedd_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '15514241028',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '44932385@N06',
#             'secret': 'ede30baf08',
#             'server': '3956',
#             'title': '#오사카 에 도착하자마자 첫번째로 먹은 음식 ㅎㅎㅎ #市場ずし #오사카 #난바 #도톤보리 #초밥 '
#                      '#스시 #Sushi #寿司 #道頓堀 #Dotonbori #Nanba #Osaka #大阪 #Japan '
#                      '#먹스타그램 #맛스타그램 #먹방 #먹방샷 #instafood #foodstargram',
#             'url_q': 'https://live.staticflickr.com/3956/15514241028_ede30baf08_q.jpg',
#             'width_q': 150},
#            {'farm': 66,
#             'height_q': 150,
#             'id': '52381133953',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '149031504@N06',
#             'secret': '9e5dc47aaa',
#             'server': '65535',
#             'title': 'Kurodai',
#             'url_q': 'https://live.staticflickr.com/65535/52381133953_9e5dc47aaa_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '22528300788',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '126884061@N08',
#             'secret': '659e21e3c1',
#             'server': '5730',
#             'title': ': 우린 계속 #배고파 #모듬초밥 순식간에 #클리어 . . . #20151107 #토요일 #한국 '
#                      '#서울 #장안동 #와쿠 # 와꾸 #WAKU #초밥 #먹스타그램 #맛스타그램 #술스타그램 #오늘 #하루 '
#                      '#일상 #데일리 #KOREAFOOD#韓国料理#韩国食品 #KOREA #韓国 #韩国 #소니 #SONY '
#                      '#RX100M3',
#             'url_q': 'https://live.staticflickr.com/5730/22528300788_659e21e3c1_q.jpg',
#             'width_q': 150},
#            {'farm': 66,
#             'height_q': 150,
#             'id': '50753685723',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '2',
#             'owner': '14340225@N03',
#             'secret': '7f5557b8c3',
#             'server': '65535',
#             'title': '뎃포 오징어 + 성게알 초밥 Squid with Uni Sushi',
#             'url_q': 'https://live.staticflickr.com/65535/50753685723_7f5557b8c3_q.jpg',
#             'width_q': 150},
#            {'farm': 2,
#             'height_q': 150,
#             'id': '25565292763',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '126344329@N08',
#             'secret': 'bfce905e02',
#             'server': '1449',
#             'title': '_  내가 좋아하는 새우 계란 참치 초밥들  내가 좋아하는걸로 제품을 만들수있어 좋다 🙌  _  '
#                      '#varzar #바잘 #볼캡 #ballcap #자수 #초밥 #스시 #초밥모자 #스시모자 #초밥볼캡 '
#                      '#스시볼캡',
#             'url_q': 'https://live.staticflickr.com/1449/25565292763_bfce905e02_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '5876926202',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '9186057@N07',
#             'secret': '6e81bf00a9',
#             'server': '5235',
#             'title': '늦은시간 초밥 한점',
#             'url_q': 'https://live.staticflickr.com/5235/5876926202_6e81bf00a9_q.jpg',
#             'width_q': 150}],
#  'total': 672}
# 1:download= https://live.staticflickr.com/5523/9596303145_f619c1ae2d_q.jpg
# 2:download= https://live.staticflickr.com/3769/9599095698_c30f68870b_q.jpg
# 3:download= https://live.staticflickr.com/7361/9599095478_a0fb4ddce1_q.jpg
# 4:download= https://live.staticflickr.com/3756/9227638860_5c3d5500d4_q.jpg
# 5:download= https://live.staticflickr.com/2903/33523410825_052f8063ca_q.jpg
# 6:download= https://live.staticflickr.com/55/115273651_614e2ab73d_q.jpg
# 7:download= https://live.staticflickr.com/4040/4617258107_ebf9cce42a_q.jpg
# 8:download= https://live.staticflickr.com/3004/2594339081_f137df97d7_q.jpg
# 9:download= https://live.staticflickr.com/2057/2546508871_cf3f2e2b14_q.jpg
# 10:download= https://live.staticflickr.com/8512/8365544608_be87eb8700_q.jpg
# 11:download= https://live.staticflickr.com/2337/2272700235_166301a38f_q.jpg
# 12:download= https://live.staticflickr.com/2012/2198722277_87b344dd50_q.jpg
# 13:download= https://live.staticflickr.com/2406/2538351058_f525f059d2_q.jpg
# 14:download= https://live.staticflickr.com/8239/8663734717_079aee75ea_q.jpg
# 15:download= https://live.staticflickr.com/2472/3755325944_69fe7c8f64_q.jpg
# 16:download= https://live.staticflickr.com/2696/4367100863_2ca73c7283_q.jpg
# 17:download= https://live.staticflickr.com/4050/4347508999_e7d1248bb4_q.jpg
# 18:download= https://live.staticflickr.com/3797/10170533083_6b01b6fa40_q.jpg
# 19:download= https://live.staticflickr.com/7141/6580102197_27031a08a1_q.jpg
# 20:download= https://live.staticflickr.com/5122/5273893013_c8cbb0006f_q.jpg
# 21:download= https://live.staticflickr.com/3005/2914638728_4be4bb415d_q.jpg
# 22:download= https://live.staticflickr.com/2821/13699444764_de9cf41488_q.jpg
# 23:download= https://live.staticflickr.com/4064/4362282117_db551ecabf_q.jpg
# 24:download= https://live.staticflickr.com/3324/3439852165_b765252ec7_q.jpg
# 25:download= https://live.staticflickr.com/3402/3656988932_5559695d69_q.jpg
# 26:download= https://live.staticflickr.com/3781/9313104038_e1c972ce44_q.jpg
# 27:download= https://live.staticflickr.com/146/364317848_beef335422_q.jpg
# 28:download= https://live.staticflickr.com/102/364317858_460dcce0e4_q.jpg
# 29:download= https://live.staticflickr.com/3051/2473738908_d3f7113e4b_q.jpg
# 30:download= https://live.staticflickr.com/164/364317864_c67dacff6b_q.jpg
# 31:download= https://live.staticflickr.com/7092/7378156626_74a82f5837_q.jpg
# 32:download= https://live.staticflickr.com/8311/7982241865_2f88818874_q.jpg
# 33:download= https://live.staticflickr.com/6082/6154654495_be27713398_q.jpg
# 34:download= https://live.staticflickr.com/6107/6854043060_286ac4700c_q.jpg
# 35:download= https://live.staticflickr.com/4047/4350359859_966474b3a6_q.jpg
# 36:download= https://live.staticflickr.com/6084/6154639033_8332c2ede4_q.jpg
# 37:download= https://live.staticflickr.com/3150/2738555364_305fdc0aa8_q.jpg
# 38:download= https://live.staticflickr.com/157/364317862_7168bc5e1f_q.jpg
# 39:download= https://live.staticflickr.com/1276/4666293342_39bf6d12da_q.jpg
# 40:download= https://live.staticflickr.com/2799/4493093951_fd34a26f30_q.jpg
# 41:download= https://live.staticflickr.com/3499/3962530402_0cbb1c4ef7_q.jpg
# 42:download= https://live.staticflickr.com/7210/6901616871_44489a0124_q.jpg
# 43:download= https://live.staticflickr.com/6023/5889913514_1c76a166b8_q.jpg
# 44:download= https://live.staticflickr.com/5265/5593852399_f322052597_q.jpg
# 45:download= https://live.staticflickr.com/5507/9169305943_455ce9b290_q.jpg
# 46:download= https://live.staticflickr.com/2721/5736064865_c8b539852b_q.jpg
# 47:download= https://live.staticflickr.com/7353/9599095168_764fae3cd6_q.jpg
# 48:download= https://live.staticflickr.com/6128/6189625424_5e1ea027d5_q.jpg
# 49:download= https://live.staticflickr.com/3061/3076416085_c1a4a08d0f_q.jpg
# 50:download= https://live.staticflickr.com/7063/6782442058_3a35649d2c_q.jpg
# 51:download= https://live.staticflickr.com/2461/3909359718_6979dc2298_q.jpg
# Traceback (most recent call last):
#   File "C:\Users\ict03_013\AppData\Local\Temp\ipykernel_11044\3585814342.py", line 29, in go_download
#     time.sleep(wait_time)
# KeyboardInterrupt

# %%
#go_download('샐러드', 'salad')

# %%
#go_download('마파두부', 'tofu')

# %% [markdown]
# 이미지를 모두 받은 후에 관련 없는 이미지들은 삭제해야 한다.

# %%
#go_download('햄버거','hamburger')

# %%
#go_download('피자','pizza')

# %%
'''
go_download('육회','yukhui')
go_download('짜장면','jjajangmyun')
go_download('감자튀김','potato')
go_download('탕수육','tangsuyuk')
go_download('돈가스', 'dongas')
go_download('물냉면', 'mul')
go_download('잡채', 'job')
go_download('햄버거', 'hamber')
go_download('치킨', 'chick')
go_download('김밥', 'kimbab')
go_download('라면', 'ramy')
go_download('족발', 'jok')
go_download('두부김치', 'dubokim')
go_download('순대', 'sundae')
'''

# %% [markdown]
# ---

# %%
#selenium으로 URL 접속하기
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd
import urllib

driver = webdriver.Chrome("D:/MyClass/Python/fML/09_photo_calorie_class/webdriver/chromedriver.exe")   


# result = []
# order = []
# menulist=['미스터피자']

# for m in menulist:
#     driver.get(f"https://web.dominos.co.kr/goods/list?dsp_ctgr=C0101")
#     time.sleep(3)
#     #product_content_name_0 > img
#     for i in range(0,18):

#         image_path = driver.find_element_by_xpath('//*[@id="product_content_name_'+str(i)+'"]/img')
#                                                     #//*[@id="product_content_name_18"]/img
#         src = image_path.get_attribute('src')
#         print(src)
#         urllib.request.urlretrieve(src, "./피자/"+m+str(i)+".png")
    
#           for i, photo in enumerate(photos['photo']):
#         url_q = photo['url_q']
#         filepath = savedir + '/' + photo['id'] + '.jpg'
#         if os.path.exists(filepath): continue
#         print(str(i + 1) + ":download=", url_q)
#         urlretrieve(url_q, filepath)
#         time.sleep(wait_time)

#     ret = pd.DataFrame(result)
#     ret.columns = ['가게명', '중분류', '주소','전화번호']
#     ret.to_csv("./"+m+".csv")
#     ordm = pd.DataFrame(order)
#     ordm.to_csv("./"+m+"메뉴.csv")

# %%
#pip install selenium
#pip install bs4
#pip install pandas

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd
import urllib


driver = webdriver.Chrome("D:/MyClass/Python/fML/09_photo_calorie_class/webdriver/chromedriver.exe")  

#웹페이지의 소스를 가져온다.
driver.get(f"https://web.dominos.co.kr/goods/list?dsp_ctgr=C0101")
time.sleep(3)
html = driver.page_source
#소스에서 img_area 클래스 하위의 소스를 가져온다.
soup = BeautifulSoup(html, 'html.parser')
img = soup.find_all(class_='lazyload')
m='도미노피자'
for i,j in enumerate(img):
    src = j["data-src"]
    print(src)
    print(i)
    urllib.request.urlretrieve(src, "./피자/"+m+str(i)+".jpg")

#이미지 경로를 받아온다.

# %%
#!pip install requests

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd
import urllib

#웹페이지의 소스를 가져온다.

driver.get(f"http://pizzaschool.net/menu/")
time.sleep(3)
html = driver.page_source
#소스에서 img_area 클래스 하위의 소스를 가져온다.
soup = BeautifulSoup(html, 'html.parser')
img = soup.find_all(class_='external-img wp-post-image')
m='피자스쿨'
print(img)

# for i,j in enumerate(img):
#     src = j["src"]
#     print(src)
#     print(i)
#     urllib.request.urlretrieve(src, "./피자/"+m+str(i)+".jpg")
# #이미지 경로를 받아온다.

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd
import urllib

#웹페이지의 소스를 가져온다.

driver.get(f"http://www.krispykreme.co.kr/menu/doughnut.asp")
time.sleep(3)
html = driver.page_source
#소스에서 img_area 클래스 하위의 소스를 가져온다.
soup = BeautifulSoup(html, 'html.parser')
img = soup.find_all(class_='cate_img')
m='크리스피도넛'
for i,j in enumerate(img):
    src = j["src"]
    src = 'http://www.krispykreme.co.kr/'+src
    print(i)
    urllib.request.urlretrieve(src, "./도넛/"+m+str(i)+".jpg")

#이미지 경로를 받아온다.

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd
import urllib
import requests

#웹페이지의 소스를 가져온다.

driver.get(f"http://www.dunkindonuts.co.kr/menu/main.php?top=A")
time.sleep(3)
html = driver.page_source
#소스에서 img_area 클래스 하위의 소스를 가져온다.
soup = BeautifulSoup(html, 'html.parser')
img = soup.select('.product > figure > img')
m='던킨도넛'

m='도미노피자'
for i,j in enumerate(img):
    src = j["src"]
    src = 'http://www.dunkindonuts.co.kr/'+src
    print(src)
    print(i)
    urllib.request.urlretrieve(src, "./도넛/"+m+str(i)+".jpg")

# %%
go_download('도넛', 'donut')

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd
import urllib
import requests

#웹페이지의 소스를 가져온다.

driver.get(f"https://www.burgerking.co.kr/#/menu/K100004/%EC%A3%BC%EB%8B%88%EC%96%B4&%EB%B2%84%EA%B1%B0")
time.sleep(3)
html = driver.page_source
#소스에서 img_area 클래스 하위의 소스를 가져온다.
soup = BeautifulSoup(html, 'html.parser')
img = soup.select('.prd_img > span > img')
m='버거킹햄버거주니어와퍼'

for i,j in enumerate(img):
    src = j["src"]
    src = src
    print(src)
    print(i)
    urllib.request.urlretrieve(src, "./햄버거/"+m+str(i)+".jpg")
