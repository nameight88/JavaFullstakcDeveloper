# %%
#!pip install xlrd
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 1.3 MB/s eta 0:00:00a 0:00:01
# ...

# %% [markdown]
# 만약에 엑셀 파일을 읽지 못하면 위에 주석을 풀어주고
# 실행해서 설치하면 엑셀파일 읽기가 가능하다.

# %%
import pandas as pd

df =pd.read_excel('data/2016-01.xls', index_col = '상품명')
df
# Out:
#                     판매건수     가격        매출
# 상품명
# 봉투                 12362     50    618100
# 바나나                 4285   3900  16711500
# 야채                  4190      0         0
# 켐벨포도                2780  29800  82844000
# 알뜰특란                2768   5300  14670400
# ...                  ...    ...       ...
# 바지락                  253      0         0
# 해표)카놀라유              253   5600   1416800
# 오)자른당면               252   5850   1474200
# 롯데)알뜰소시지             252   4400   1108800
# 한돈앞다리/불고기,찌개(국내산)    252      0         0
#
# [200 rows x 3 columns]

# %% [markdown]
# 판다스 내에서 엑셀 파일을 읽을 수 있는 기능이 있다.
# 열의 indexcol을 이용을 해서 열의 제목을 부여를 해줌

# %% [markdown]
# #### 판다스 데이타프레임의 기본적인 정보 얻어오기
#
# - 앞에 10개 행 보기
# - 뒤에 10개 행 보기
#
# - 판매건수에서 큰 값 순으로 10개 (nlargest()이용)
# - 판매건수에서 작은 값 순으로 10개 (nsmallest()이용)

# %%
df.head(10)
# Out:
#         판매건수     가격        매출
# 상품명
# 봉투     12362     50    618100
# 바나나     4285   3900  16711500
# 야채      4190      0         0
# 켐벨포도    2780  29800  82844000
# 알뜰특란    2768   5300  14670400
# 딸기      2234      0         0
# 팔음산포도   2161  19800  42787800
# 봉투      2038     30     61140
# 애호박     1962   1490   2923380
# 청양고추    1901      0         0

# %%
df.tail(10)
# Out:
#                    판매건수    가격       매출
# 상품명
# 황도복숭아               258     0        0
# CJ)주부초밥왕(소풍)        256  3750   960000
# 온동네광천파래재래김(전장)      255  2550   650250
# 새송이버섯               255     0        0
# CJ)행콩나물             253  1950   493350
# 바지락                 253     0        0
# 해표)카놀라유             253  5600  1416800
# 오)자른당면              252  5850  1474200
# 롯데)알뜰소시지            252  4400  1108800
# 한돈앞다리/불고기,찌개(국내산)   252     0        0

# %%
df.nlargest(10,'판매건수')
# Out:
#         판매건수     가격        매출
# 상품명
# 봉투     12362     50    618100
# 바나나     4285   3900  16711500
# 야채      4190      0         0
# 켐벨포도    2780  29800  82844000
# 알뜰특란    2768   5300  14670400
# 딸기      2234      0         0
# 팔음산포도   2161  19800  42787800
# 봉투      2038     30     61140
# 애호박     1962   1490   2923380
# 청양고추    1901      0         0

# %%
df.nsmallest(10,["판매건수","가격"])
#판매건수가 제일 적은걸 출력을 하는데 거기서 또 가격이 오름차순으로 출력
#nsmallest 에서 컬럼을 2가지를 넣으면 함수가 적용이 되고 또 그 컬럼 안에서 오름차순으로 한번더 정렬을 해준다.
# Out:
#                    판매건수    가격       매출
# 상품명
# 한돈앞다리/불고기,찌개(국내산)   252     0        0
# 롯데)알뜰소시지            252  4400  1108800
# 오)자른당면              252  5850  1474200
# 바지락                 253     0        0
# CJ)행콩나물             253  1950   493350
# 해표)카놀라유             253  5600  1416800
# 새송이버섯               255     0        0
# 온동네광천파래재래김(전장)      255  2550   650250
# CJ)주부초밥왕(소풍)        256  3750   960000
# 황도복숭아               258     0        0

# %% [markdown]
# -판매건수 기준으로 최대와 최소를 10개씩 출력하는 함수
# -몇개 까지 출력할지와 어떤 컬럼 기준으로 출력을 할건지 지정을 해줘야한다.

# %% [markdown]
# #### 컬럼으로 추출
#
# - 컬럼명들을 출력
# - 판매건수 데이타 출력

# %%
df.columns
#어떤 컬럼(인덱스)를 갖고 있는지 출력
# Out:
# Index(['판매건수', '가격', '매출'], dtype='object')

# %%
df['판매건수']

- 1번째 행 레코드 출력
- '바나나' 행 레코드 출력
# Out:
# 상품명
# 봉투                   12362
# 바나나                   4285
# 야채                    4190
# 켐벨포도                  2780
# 알뜰특란                  2768
#                      ...
# 바지락                    253
# 해표)카놀라유                253
# 오)자른당면                 252
# 롯데)알뜰소시지               252
# 한돈앞다리/불고기,찌개(국내산)      252
# Name: 판매건수, Length: 200, dtype: int64

# %%
df[["판매건수"]]
# Out:
#                     판매건수
# 상품명
# 봉투                 12362
# 바나나                 4285
# 야채                  4190
# 켐벨포도                2780
# 알뜰특란                2768
# ...                  ...
# 바지락                  253
# 해표)카놀라유              253
# 오)자른당면               252
# 롯데)알뜰소시지             252
# 한돈앞다리/불고기,찌개(국내산)    252
#
# [200 rows x 1 columns]

# %%
print(type(df["판매건수"]))
print(type(df[["판매건수"]]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# #### df["판매건수"] 와 df[["판매건수의 차이]]
# 둘의 출력 방식보다도 둘의 자료형은 []하나 더 추가해줌으로 달라진다.
# []한개일 경우 판다스 내에 있는 시리즈의 자료형을 가지고
# [[]]이 방식의 경우 판다스 내에 있는 데이터프라임이라는 자료형을 가지고 있기 떄문에
# 상황에 맞게 사용을 해준다.

# %% [markdown]
# #### 일련번호로 데이타 추출
#
# - 1번째 행 레코드 출력
# - '바나나' 행 레코드 출력

# %%
#열(세로)에서 숫자로 몇번째에 있는지로 찾는 방법
df.iloc[1]
# Out:
# 판매건수        4285
# 가격          3900
# 매출      16711500
# Name: 바나나, dtype: int64

# %%
#열(세로)에서 컬럼의 이름으로 찾는 방법
df.loc["바나나"]
# Out:
#      판매건수    가격        매출
# 상품명
# 바나나  4285  3900  16711500
# 바나나  1213     0         0

# %% [markdown]
# -df.loc[] -> 인덱스명으로 찾아가는 것이고
# -df.iloc[] -> 인덱스명이 아니라 일련번호로 찾아가는것이다.

# %% [markdown]
# #### 행에서 데이타 추출
#
# - 야채, 딸기, 봉투행을 추출하여 매출순으로 정렬하기 (sort_values()이용)
# - 바나나행부터 딸기행까지 추출
# - 야채부터 딸기행까지 추출

# %%
sangpum = df.loc[["야채","딸기","봉투"]]
print(sangpum)
# Out:
#       판매건수  가격      매출
# 상품명
# 야채    4190   0       0
# 딸기    2234   0       0
# 봉투   12362  50  618100
# 봉투    2038  30   61140

# %%
sangpum = ["야채","딸기","봉투"]  
df.loc[sangpum]
# Out:
#       판매건수  가격      매출
# 상품명
# 야채    4190   0       0
# 딸기    2234   0       0
# 봉투   12362  50  618100
# 봉투    2038  30   61140

# %% [markdown]
# 위의 두번의 방식을 df.loc으로 한번에 찾아서 그 결과를 변수에 담아서
# print를 이용을 해서 출력을 하는 방식과
# 범위를 구하는 것을 변수에 담아서 출력을 하는 방식
# 취향 차이

# %%
df.loc[["야채","딸기","봉투"]].sort_values('매출', ascending=False)
# Out:
#       판매건수  가격      매출
# 상품명
# 봉투   12362  50  618100
# 봉투    2038  30   61140
# 야채    4190   0       0
# 딸기    2234   0       0

# %% [markdown]
# 첫번째에 by값으로 어떤거 기준으로 볼지를 지정을 해주소
# 기본값이 ascending이 True값으로 설정이 되어있는데 False값으로
# 바꿔주면서 오름차순 정렬에서 내림차순 정렬로 바꿔준다.

# %%
df.loc["야채":"딸기"]
# Out:
#       판매건수     가격        매출
# 상품명
# 야채    4190      0         0
# 켐벨포도  2780  29800  82844000
# 알뜰특란  2768   5300  14670400
# 딸기    2234      0         0

# %%
df.iloc[1:5]
# Out:
#       판매건수     가격        매출
# 상품명
# 바나나   4285   3900  16711500
# 야채    4190      0         0
# 켐벨포도  2780  29800  82844000
# 알뜰특란  2768   5300  14670400

# %% [markdown]
# #### 조건으로 검색
#
# - 가격이 10000 초과 상품 출력
# - 가격이 10000에서 20000 사이 상품 출력

# %%
df['가격']
# Out:
# 상품명
# 봉투                      50
# 바나나                   3900
# 야채                       0
# 켐벨포도                 29800
# 알뜰특란                  5300
#                      ...
# 바지락                      0
# 해표)카놀라유               5600
# 오)자른당면                5850
# 롯데)알뜰소시지              4400
# 한돈앞다리/불고기,찌개(국내산)        0
# Name: 가격, Length: 200, dtype: int64

# %%
condi = dfdf['가격']> 10000
df[condi]
# Out:
#              판매건수     가격        매출
# 상품명
# 켐벨포도         2780  29800  82844000
# 팔음산포도        2161  19800  42787800
# 동서)맥심모카골드믹스   380  23800   9044000
# 감귤            297  29800   8850600

# %% [markdown]
# df['가격']> 10000 이렇게만 입력을 할 경우
# True False 값만 나오게 되기 떄문에 df[]안에 다음과 같이 넣어주게 되면
# 그 값에 해당되는 컬럼들만 출력
#
# df[df['가격']> 10000]
#
# 이 조건 들을 변수로 잡아줘서 안에 넣어주는 방법도 있다.
# condi = dfdf['가격']> 10000
# df[condi]

# %%
diTest = (df["가격"] < 20000) & (df["가격"] > 10000)
df[diTest]
# Out:
#        판매건수     가격        매출
# 상품명
# 팔음산포도  2161  19800  42787800

# %% [markdown]
# and 또는 or 연산자로는 안되기 때문에 기호 연산자 & 나 | 를 이용해서
# 조건을 걸어주고 또 조건들을 ()로 묶어줘야한다.

# %% [markdown]
# #### 판매건수로 정렬

# %%
df.sort_values("판매건수")[:10]
# Out:
#                    판매건수    가격       매출
# 상품명
# 한돈앞다리/불고기,찌개(국내산)   252     0        0
# 롯데)알뜰소시지            252  4400  1108800
# 오)자른당면              252  5850  1474200
# CJ)행콩나물             253  1950   493350
# 해표)카놀라유             253  5600  1416800
# 바지락                 253     0        0
# 새송이버섯               255     0        0
# 온동네광천파래재래김(전장)      255  2550   650250
# CJ)주부초밥왕(소풍)        256  3750   960000
# 황도복숭아               258     0        0

# %%
result =df.sort_values("판매건수",ascending=False)[0:10]
#print(type(result)) 자료형 구조는 데이터프레임 구조를 띄고 있다.

# %% [markdown]
# 판매건수를 기준으로 출력을 하는데 내림차순으로 10개까지만 출력을 한다.

# %%
df.sort_values("판매건수",ascending=False)[10:20]
# Out:
#            판매건수    가격       매출
# 상품명
# 상추         1695     0        0
# 오)맛있는밥기획   1689  4450  7516050
# 대파         1687  2980  5027260
# 양파(소)      1655  2900  4799500
# 강릉초당)왕콩나물  1529  1950  2981550
# 백오이        1500  1490  2235000
# 블루베리       1498  2980  4464040
# 느타리버섯      1497  1290  1931130
# 청과         1458     0        0
# 무우         1408  1980  2787840

# %% [markdown]
# 판매건수 기준으로 내림차순으로 10번째부터 20번쨰까지 출력

# %%
df.sort_values(["판매건수","가격"],ascending=False)[10:20]
# Out:
#            판매건수    가격       매출
# 상품명
# 상추         1695     0        0
# 오)맛있는밥기획   1689  4450  7516050
# 대파         1687  2980  5027260
# 양파(소)      1655  2900  4799500
# 강릉초당)왕콩나물  1529  1950  2981550
# 백오이        1500  1490  2235000
# 블루베리       1498  2980  4464040
# 느타리버섯      1497  1290  1931130
# 청과         1458     0        0
# 무우         1408  1980  2787840

# %% [markdown]
# 10번째 부터 20번째까찌 출력

# %%
sangpum=["판매건수","가격"]
df.sort_values(sangpum,ascending=False)[10:20]

# %%
sangpum=["판매건수","가격"]
df.sort_values(sangpum,ascending=[True,False])
# Out:
#              판매건수    가격       매출
# 상품명
# 롯데)갸또쇼콜라      259  3950  1023050
# 삼립)호빵(단팥야채)   260  5500  1430000
# 코카콜라PET       260  2690   699400
# 풀)국산콩나물       260  2100   546000
# 한돈불고기(국내산)    261     0        0
# 꼬막            264     0        0
# 파프리카          265     0        0
# 미닛)망고100      266  2950   784700
# 한성)튀김우동       266  1450   385700
# 한성)미니윈너       274  4350  1191900

# %% [markdown]
# ascending에서 리스트로 조건을 걸어줘서 1번째는 오름차순으로 출력을 하고
# 2번째는 내림차순으로 정렬해서 출력하게 설정이 가능하다.

# %% [markdown]
# #### 가격순으로 정렬하되 판매건수와 가격만 추출

# %%
sangpum=df[["가격","판매건수"]].sort_values("가격",ascending=True)[:10]
sangpum
# Out:
#                    가격  판매건수
# 상품명
# 한돈앞다리/불고기,찌개(국내산)   0   252
# 양배추                 0  1183
# 깐양파                 0   409
# 청포도                 0   418
# 한돈목살구이(국내산)         0   478
# 하림닭도리탕(국내산)         0   481
# 섬초                  0   496
# 사과                  0   510
# 특수야채류               0   520
# 켐벨포도                0   552

# %% [markdown]
# sangpum=df[["가격","판매건수"]]
# sangpum.sort_values("가격",ascending=True)
# 우선 첫번째로 df에서 내가 원하는 컬럼들을 저장할 것들을 추출해서
# 변수에 저장 후 정렬을 하는거에서 가격을 기준으로 하고
# 내림차순 조건을 걸어준 후에 출력

# %%
sangpum=df[["가격","판매건수"]].sort_values("가격",ascending=True)[:10]
sangpum["판매건수"].plot(kind="bar")
# Out:
# <Axes: xlabel='상품명'>
# /Users/namdawis/anaconda3/lib/python3.11/site-packages/IPython/core/events.py:93: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   func(*args, **kwargs)
# /Users/namdawis/anaconda3/lib/python3.11/site-packages/IPython/core/events.py:93: UserWarning: Glyph 46024 (\N{HANGUL SYLLABLE DON}) missing from current font.
#   func(*args, **kwargs)
# /Users/namdawis/anaconda3/lib/python3.11/site-packages/IPython/core/events.py:93: UserWarning: Glyph 50526 (\N{HANGUL SYLLABLE AP}) missing from current font.
#   func(*args, **kwargs)
# /Users/namdawis/anaconda3/lib/python3.11/site-packages/IPython/core/events.py:93: UserWarning: Glyph 45796 (\N{HANGUL SYLLABLE DA}) missing from current font.
#   func(*args, **kwargs)
# /Users/namdawis/anaconda3/lib/python3.11/site-packages/IPython/core/events.py:93: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   func(*args, **kwargs)
# ...

# %% [markdown]
# 이렇게 데이터를 가공하고나서 plot함수를 이용해서 그래프 처리도 가능하다
